# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist

# %%
def make_data(N, d , rseed=1):
    rand = np.random.RandomState(rseed)
    x = rand.randn(N*d)
    x = np.reshape(x , (N , d))
    return x

def distance(x , N , d):
    x_distance = [];
    for i in range(N-1):
        for j in (i+1 ,N-1) :
            dist = 0
            for dim in range(d):
                dist = dist + np.power(x[i][dim]-x[j][dim],2)
            x_distance.append(np.sqrt(dist))
    return x_distance

# %%
x = make_data(1000 , 5)
x_distance = distance(x ,1000 , 5)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("5 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(1000 , 2000)
x_distance = distance(x ,1000 , 2000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("2000 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(1000 , 5000)
x_distance = distance(x ,1000 , 5000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("5000 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(1000 , 10000)
x_distance = distance(x ,1000 , 10000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("10000 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(1000 , 1000000)
#x_distance = distance(x ,1000 , 1000000)
x_distance = pdist(x, metric = 'euclidean')
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("1000000 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(1000 , 10000)
x_distance = distance(x ,1000 , 10000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("10000 Dimension-1000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(2000 , 10000)
x_distance = distance(x ,2000 , 10000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("10000 Dimension-2000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(5000 , 10000)
x_distance = distance(x ,5000 , 10000)
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("10000 Dimension-5000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')

# %%
x = make_data(10000 , 10000)
#x_distance = distance(x ,10000 , 10000)
x_distance = pdist(x, metric = 'euclidean')
hist_distance = plt.hist(x_distance, bins=40, density=True)
plt.title("10000 Dimension-10000 DataPoint")
plt.xlabel("Distance")
# Out:
# Text(0.5, 0, 'Distance')
